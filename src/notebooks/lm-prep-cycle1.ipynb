# %%
import os
import sys
import operator

import pandas as pd
import numpy as np

from langdetect import detect

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from data_input.load_data import load_corpus

import readability
import spacy

# %%
# load the data for the three evaluation cycles
corpus1 = load_corpus("../../data/data_cycle1")

# %%
corpus1.shape
# Out:
# (32387, 14)

# %%
# filter German language arguments
def detect_language(text):
    try:
        return detect(text)
    except:
        return None

def detect_languages_in_dataset(argu_corpus):
    argu_corpus['language'] = argu_corpus['argument'].apply(detect_language)
    return argu_corpus

result_langu_df = detect_languages_in_dataset(corpus1)
corpus_de = result_langu_df[result_langu_df['language'] == 'de']
corpus_de = corpus_de.reset_index(drop=True)

# %%
corpus_de.shape
# Out:
# (22353, 15)

# %%
corpus_de
# Out:
#        argument_id                                           argument  \
# 0           201900  Das Schweizer Volk hat die MEI angenommen und ...
# 1           201901  Eine Legalisierung von Cannabis entlasten die ...
# 2           201902  Durch die Förderung der familienergänzenden Be...
# 3           201903  Ich ziehe eine Elternzeit vor. Die Zeit nach d...
# 4           201904  Unser Asylrecht muss konsequent angewendet wer...
# ...            ...                                                ...
# 22348   2019031140  Das Stimmrechtsalter ab 16 könnte prinzipiell ...
# 22349   2019031147  Die heutige Technologie erlangt eigentlich E-V...
# 22350   2019031148  Nur Volljaehrige sollen weiter stimmrechtig bl...
# 22351   2019031162  La transparence est une vertue.\n\nTransparenz...
# 22352   2019031452  Privatpersonen mit kleinen Spendenbeträgen sol...
#
#         stance             topic    gender    age residence civil_status  \
# 0        FAVOR       Immigration  Männlich  18-34      Land        Ledig
# 1        FAVOR           Society  Männlich  18-34      Land        Ledig
# 2        FAVOR           Welfare  Weiblich  35-49      Land        Ledig
# 3      AGAINST           Welfare  Weiblich  35-49      Land        Ledig
# 4      AGAINST       Immigration  Weiblich  35-49      Land        Ledig
# ...        ...               ...       ...    ...       ...          ...
# 22348    FAVOR  Political System  Weiblich  35-49      Land  Verheiratet
# 22349    FAVOR  Political System  Weiblich  50-64      Land        Ledig
# 22350  AGAINST  Political System  Weiblich  50-64      Land        Ledig
# 22351    FAVOR  Political System  Männlich  35-49      Land  Verheiratet
# 22352    FAVOR  Political System  Weiblich  50-64      Land  Verheiratet
#
#                                denomination       education  \
# 0                         Christ-katholisch  Fachhochschule
# 1                         Christ-katholisch  Fachhochschule
# 2                             Nicht bekannt     Universität
# 3                             Nicht bekannt     Universität
# 4                             Nicht bekannt     Universität
# ...                                     ...             ...
# 22348  Evangelischreformiert/protestantisch     Universität
# 22349                    Römisch-katholisch     Universität
# 22350                    Römisch-katholisch     Universität
# 22351                    Römisch-katholisch   Nicht bekannt
# 22352  Evangelischreformiert/protestantisch   Nicht bekannt
#
#                   political_spectrum  \
# 0      Mitte und Konservativ-Liberal
# 1      Mitte und Konservativ-Liberal
# 2              Mitte und Konservativ
# 3              Mitte und Konservativ
# 4              Mitte und Konservativ
# ...                              ...
# 22348  Links und Konservativ-Liberal
# 22349  Mitte und Konservativ-Liberal
# 22350  Mitte und Konservativ-Liberal
# 22351  Links und Konservativ-Liberal
# 22352          Mitte und Konservativ
#
#                               important_political_issues   rile  \
# 0      [Liberale Wirtschaftspolitik, Restriktive Migr...  Mitte
# 1      [Liberale Wirtschaftspolitik, Restriktive Migr...  Mitte
# 2      [Offene Aussenpolitik, Liberale Wirtschaftspol...  Mitte
# 3      [Offene Aussenpolitik, Liberale Wirtschaftspol...  Mitte
# 4      [Offene Aussenpolitik, Liberale Wirtschaftspol...  Mitte
# ...                                                  ...    ...
# 22348  [Ausgebauter Umweltschutz, Ausgebauter Sozials...  Links
# 22349  [Ausgebauter Umweltschutz, Ausgebauter Sozials...  Mitte
# 22350  [Ausgebauter Umweltschutz, Ausgebauter Sozials...  Mitte
# 22351  [Offene Aussenpolitik, Law & Order, Ausgebaute...  Links
# 22352  [Offene Aussenpolitik, Liberale Wirtschaftspol...  Mitte
#
#                     galtan language
# 0      Konservativ-Liberal       de
# 1      Konservativ-Liberal       de
# 2              Konservativ       de
# 3              Konservativ       de
# 4              Konservativ       de
# ...                    ...      ...
# 22348  Konservativ-Liberal       de
# 22349  Konservativ-Liberal       de
# 22350  Konservativ-Liberal       de
# 22351  Konservativ-Liberal       de
# 22352          Konservativ       de
#
# [22353 rows x 15 columns]

# %% [markdown]
# # Preprocessing
# #### Clean data to improve meaningfulness of results

# %%
ind_variables1 = ["gender", "age", "residence", "civil_status", "denomination", "education", 
                  "rile", "galtan", "important_political_issues"]
ind_variables2 = ["stance", "topic"]

# %%
# check sparsity
[corpus_de[col].value_counts() for col in ind_variables1]
# Out:
# [gender
#  Männlich    14308
#  Weiblich     8045
#  Name: count, dtype: int64,
#  age
#  18-34    7467
#  50-64    7215
#  35-49    6393
#  65+      1278
#  Name: count, dtype: int64,
#  residence
#  Land     20257
#  Stadt     2096
#  Name: count, dtype: int64,
#  civil_status
#  Verheiratet                   8190
#  Nicht bekannt                 7566
#  Ledig                         5294
#  Geschieden                     575
#  Konkubinat                     395
#  Verwitwet                      234
#  Eingetragene Partnerschaft      52
#  Getrennt                        46
#  Aufgelöste Partnerschaft         1
#  Name: count, dtype: int64,
#  denomination
#  Nicht bekannt                             9018
#  Evangelischreformiert/protestantisch      5484
#  Römisch-katholisch                        4221
#  Konfessionslos                            2993
#  Andere christliche Gemeinschaften          506
#  Christ-katholisch                           69
#  Christlich-orthodox                         22
#  Andere Kirchen/Religionsgemeinschaften      17
#  Jüdische Gemeinschaften                     14
#  Islamische Gemeinschaften                    9
#  Name: count, dtype: int64,
#  education
#  Universität                  7007
#  Nicht bekannt                6207
#  Fachhochschule               2926
#  Berufslehre/Berufsschule     1737
#  Gymnasium/Seminar            1223
#  Höhere Berufsausbildung      1097
#  Höhere Fachschule             878
#  Berufsmatura                  372
#  Anderer Bildungsabschluss     235
#  Sekundarschule                220
#  Handelsschule                 168
#  Diplommittelschule            157
#  Primarschule/Realschule       126
#  Name: count, dtype: int64,
#  rile
#  Links     12057
#  Mitte      8733
#  Rechts     1563
#  Name: count, dtype: int64,
#  galtan
#  Konservativ-Liberal    14378
#  Konservativ             6621
#  Liberal                 1354
#  Name: count, dtype: int64,
#  important_political_issues
#  [Offene Aussenpolitik, Ausgebauter Umweltschutz, Ausgebauter Sozialstaat, Liberale Gesellschaft]                    4109
#  [Offene Aussenpolitik, Ausgebauter Umweltschutz, Ausgebauter Sozialstaat]                                           2258
#  [Ausgebauter Umweltschutz, Ausgebauter Sozialstaat, Liberale Gesellschaft]                                          1907
#  [Offene Aussenpolitik, Liberale Wirtschaftspolitik, Liberale Gesellschaft]                                          1217
#  [Offene Aussenpolitik, Liberale Wirtschaftspolitik, Ausgebauter Umweltschutz, Liberale Gesellschaft]                1029
#                                                                                                                      ...
#  [Offene Aussenpolitik, Restriktive Migrationspolitik, Ausgebauter Umweltschutz]                                        1
#  [Law & Order, Ausgebauter Umweltschutz, Liberale Gesellschaft]                                                         1
#  [Offene Aussenpolitik, Ausgebauter Sozialstaat]                                                                        1
#  [Liberale Wirtschaftspolitik, Ausgebauter Umweltschutz, Ausgebauter Sozialstaat]                                       1
#  [Offene Aussenpolitik, Liberale Wirtschaftspolitik, Law & Order, Ausgebauter Sozialstaat, Liberale Gesellschaft]       1
#  Name: count, Length: 115, dtype: int64]

# %%
# Summarize groups
corpus_de.loc[corpus_de["education"] == "Höhere Fachschule", 
              "education"] = "Höhere Berufsausbildung"
corpus_de.loc[corpus_de["education"] == "Handelsschule", 
              "education"] = "Höhere Berufsausbildung"
corpus_de.loc[corpus_de["education"] == "Berufsmatura", 
              "education"] = "Berufsmatura/Diplommittelschule"
corpus_de.loc[corpus_de["education"] == "Diplommittelschule", 
              "education"] = "Berufsmatura/Diplommittelschule"

# %%
# Drop groups with rare occurences (<50)
corpus_de = corpus_de.drop(corpus_de[
    corpus_de["civil_status"].isin(["Getrennt"])].index)
corpus_de = corpus_de.drop(corpus_de[
    corpus_de["civil_status"].isin(["Aufgelöste Partnerschaft"])].index)

corpus_de = corpus_de.drop(corpus_de[
    corpus_de["denomination"].isin(["Christlich-orthodox"])].index)
corpus_de = corpus_de.drop(corpus_de[
    corpus_de["denomination"].isin(["Andere Kirchen/Religionsgemeinschaften"])].index)
corpus_de = corpus_de.drop(corpus_de[
    corpus_de["denomination"].isin(["Jüdische Gemeinschaften"])].index)
corpus_de = corpus_de.drop(corpus_de[
    corpus_de["denomination"].isin(["Islamische Gemeinschaften"])].index)

# %%
# Drop rows with missing values
corpus_de = corpus_de.drop(corpus_de[corpus_de["civil_status"].isin(["Nicht bekannt"])].index)
corpus_de = corpus_de.drop(corpus_de[corpus_de["denomination"].isin(["Nicht bekannt"])].index)
corpus_de = corpus_de.drop(corpus_de[corpus_de["education"].isin(["Nicht bekannt"])].index)

# %%
[corpus_de[col].value_counts() for col in ind_variables1]
# Out:
# [gender
#  Männlich    7474
#  Weiblich    3815
#  Name: count, dtype: int64,
#  age
#  50-64    3830
#  35-49    3563
#  18-34    3320
#  65+       576
#  Name: count, dtype: int64,
#  residence
#  Land     10301
#  Stadt      988
#  Name: count, dtype: int64,
#  civil_status
#  Verheiratet                   6417
#  Ledig                         3904
#  Geschieden                     417
#  Konkubinat                     369
#  Verwitwet                      130
#  Eingetragene Partnerschaft      52
#  Name: count, dtype: int64,
#  denomination
#  Evangelischreformiert/protestantisch    4801
#  Römisch-katholisch                      3438
#  Konfessionslos                          2496
#  Andere christliche Gemeinschaften        490
#  Christ-katholisch                         64
#  Name: count, dtype: int64,
#  education
#  Universität                        4903
#  Fachhochschule                     2007
#  Höhere Berufsausbildung            1488
#  Berufslehre/Berufsschule           1288
#  Gymnasium/Seminar                   874
#  Berufsmatura/Diplommittelschule     347
#  Anderer Bildungsabschluss           148
#  Sekundarschule                      132
#  Primarschule/Realschule             102
#  Name: count, dtype: int64,
#  rile
#  Links     5667
#  Mitte     4876
#  Rechts     746
#  Name: count, dtype: int64,
#  galtan
#  Konservativ-Liberal    7140
#  Konservativ            3563
#  Liberal                 586
#  Name: count, dtype: int64,
#  important_political_issues
#  [Offene Aussenpolitik, Ausgebauter Umweltschutz, Ausgebauter Sozialstaat, Liberale Gesellschaft]                    1795
#  [Offene Aussenpolitik, Ausgebauter Umweltschutz, Ausgebauter Sozialstaat]                                           1178
#  [Offene Aussenpolitik, Liberale Wirtschaftspolitik, Liberale Gesellschaft]                                           701
#  [Ausgebauter Umweltschutz, Ausgebauter Sozialstaat, Liberale Gesellschaft]                                           689
#  [Offene Aussenpolitik, Liberale Wirtschaftspolitik, Ausgebauter Umweltschutz, Liberale Gesellschaft]                 555
#                                                                                                                      ...
#  [Restriktive Finanzpolitik, Law & Order]                                                                               1
#  [Offene Aussenpolitik]                                                                                                 1
#  [Liberale Wirtschaftspolitik, Law & Order, Ausgebauter Umweltschutz]                                                   1
#  [Offene Aussenpolitik, Liberale Gesellschaft]                                                                          1
#  [Offene Aussenpolitik, Liberale Wirtschaftspolitik, Law & Order, Ausgebauter Sozialstaat, Liberale Gesellschaft]       1
#  Name: count, Length: 88, dtype: int64]

# %%
corpus_de.shape
# Out:
# (11289, 15)

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# ### Surface features

# %%
corpus_de['FleschReadingEase'] = corpus_de['argument'].apply(lambda x: readability.getmeasures(x, lang='de')['readability grades']['FleschReadingEase'])
corpus_de['GunningFogIndex'] = corpus_de['argument'].apply(lambda x: readability.getmeasures(x, lang='de')['readability grades']['GunningFogIndex'])

corpus_de['characters_per_word'] = corpus_de['argument'].apply(lambda x: readability.getmeasures(x, lang='de')['sentence info']['characters_per_word'])
corpus_de['words_per_sentence'] = corpus_de['argument'].apply(lambda x: readability.getmeasures(x, lang='de')['sentence info']['words_per_sentence'])
corpus_de['type_token_ratio'] = corpus_de['argument'].apply(lambda x: readability.getmeasures(x, lang='de')['sentence info']['type_token_ratio'])
corpus_de['long_words'] = corpus_de['argument'].apply(lambda x: readability.getmeasures(x, lang='de')['sentence info']['long_words'])
corpus_de['complex_words'] = corpus_de['argument'].apply(lambda x: readability.getmeasures(x, lang='de')['sentence info']['complex_words'])

# %%
corpus_de.head()
# Out:
#     argument_id                                           argument stance  \
# 0        201900  Das Schweizer Volk hat die MEI angenommen und ...  FAVOR
# 1        201901  Eine Legalisierung von Cannabis entlasten die ...  FAVOR
# 33      2019054  Die jetzige finanzielle Situation der Pensions...  FAVOR
# 34      2019055  Dort wo die Leistungen nicht angebracht sind, ...  FAVOR
# 35      2019056  Wünschenswert, aber eine Herkulesaufgabe für d...  FAVOR
#
#           topic    gender    age residence civil_status  \
# 0   Immigration  Männlich  18-34      Land        Ledig
# 1       Society  Männlich  18-34      Land        Ledig
# 33      Welfare  Männlich  50-64      Land  Verheiratet
# 34      Welfare  Männlich  50-64      Land  Verheiratet
# 35    Education  Männlich  50-64      Land  Verheiratet
#
#                             denomination                education  ...   rile  \
# 0                      Christ-katholisch           Fachhochschule  ...  Mitte
# 1                      Christ-katholisch           Fachhochschule  ...  Mitte
# 33  Evangelischreformiert/protestantisch  Höhere Berufsausbildung  ...  Mitte
# 34  Evangelischreformiert/protestantisch  Höhere Berufsausbildung  ...  Mitte
# 35  Evangelischreformiert/protestantisch  Höhere Berufsausbildung  ...  Mitte
#
#                  galtan language FleschReadingEase GunningFogIndex  \
# 0   Konservativ-Liberal       de         25.703448       15.737931
# 1   Konservativ-Liberal       de          7.991154       13.476923
# 33  Konservativ-Liberal       de         26.470000        8.036364
# 34  Konservativ-Liberal       de         44.405000       12.000000
# 35  Konservativ-Liberal       de        -34.129231       11.353846
#
#     characters_per_word  words_per_sentence  type_token_ratio  long_words  \
# 0              5.758621                29.0          0.896552           9
# 1              6.576923                26.0          0.923077          11
# 33             6.545455                11.0          1.000000           6
# 34             6.000000                10.0          1.000000           4
# 35             7.923077                13.0          0.923077           7
#
#     complex_words
# 0               3
# 1               2
# 33              1
# 34              2
# 35              2
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Mean and standard deviation for the features

# %%
surface_features = ['FleschReadingEase', 'GunningFogIndex', 'characters_per_word', 
                             'words_per_sentence', 'type_token_ratio', 'long_words', 'complex_words']

# %%
for feat in surface_features:
    print(feat, round(corpus_de[feat].mean(),2), round(corpus_de[feat].min(),2), 
          round(corpus_de[feat].max(),2), round(corpus_de[feat].std(),2))
# Out:
# FleschReadingEase 19.15 -177.92 103.7 27.65
# GunningFogIndex 14.33 1.4 36.4 6.23
# characters_per_word 6.41 3.75 14.25 0.96
# words_per_sentence 23.36 3.5 85.0 14.26
# type_token_ratio 0.95 0.64 1.0 0.06
# long_words 8.89 0 32 5.63
# complex_words 2.95 0 15 2.28

# %% [markdown]
# ### Syntactic features

# %%
#ADJ: adjective
#ADP: adposition
#ADV: adverb
#AUX: auxiliary
#CCONJ: coordinating conjunction
#DET: determiner
#INTJ: interjection
#NOUN: noun
#NUM: numeral
#PART: particle
#PRON: pronoun
#PROPN: proper noun
#PUNCT: punctuation
#SCONJ: subordinating conjunction
#SYM: symbol
#VERB: verb
#X: other

upos_tags = ['ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 
             'PROPN', 'PUNCT', 'SCONJ', 'SYM', 'VERB', 'X']

nlp = spacy.load("de_core_news_sm")


def pos_features(text):
    doc = nlp(text)
    doc_pos = [token.pos_ for token in doc]
    doc_length = len(doc_pos)
    counts = {tag: doc_pos.count(tag)/doc_length for tag in upos_tags} # proportion of pos tags in text
    return counts


def entity_feature(text):
    doc = nlp(text)
    doc_ent = [token.ent_iob_ for token in doc]
    doc_length = len(doc_ent)
    count = (doc_ent.count('B')+doc_ent.count('I'))/doc_length # proportion of entities in text
    return count


def morph_features(text):
    doc = nlp(text)
    doc_morph = [token.morph for token in doc]
    doc_length = len(doc_morph)
    tense = sum([1 for token in doc_morph if "Tense=Pres" in token])/doc_length
    mood = sum([1 for token in doc_morph if "Mood=Imp" in token])/doc_length
    person = sum([1 for token in doc_morph if "Person=1" in token])/doc_length
    return {"pres_tense": tense, "imperative": mood, "first_person": person}

# %%
# add column with pos tags (as dict)
corpus_de['POS'] = corpus_de['argument'].apply(lambda x: pos_features(x))
# pos dict to single columns
corpus_de = pd.concat([corpus_de, corpus_de['POS'].apply(pd.Series)], axis=1)
corpus_de = corpus_de.drop('POS', axis=1)

# %%
# add column with entity ratio
corpus_de['Entities'] = corpus_de['argument'].apply(lambda x: entity_feature(x))

# %%
# add column with morphology features
corpus_de['Morph'] = corpus_de['argument'].apply(lambda x: morph_features(x))
# morph dict to single columns
corpus_de = pd.concat([corpus_de, corpus_de['Morph'].apply(pd.Series)], axis=1)
corpus_de = corpus_de.drop('Morph', axis=1)

# %%
corpus_de.head()
# Out:
#     argument_id                                           argument stance  \
# 0        201900  Das Schweizer Volk hat die MEI angenommen und ...  FAVOR
# 1        201901  Eine Legalisierung von Cannabis entlasten die ...  FAVOR
# 33      2019054  Die jetzige finanzielle Situation der Pensions...  FAVOR
# 34      2019055  Dort wo die Leistungen nicht angebracht sind, ...  FAVOR
# 35      2019056  Wünschenswert, aber eine Herkulesaufgabe für d...  FAVOR
#
#           topic    gender    age residence civil_status  \
# 0   Immigration  Männlich  18-34      Land        Ledig
# 1       Society  Männlich  18-34      Land        Ledig
# 33      Welfare  Männlich  50-64      Land  Verheiratet
# 34      Welfare  Männlich  50-64      Land  Verheiratet
# 35    Education  Männlich  50-64      Land  Verheiratet
#
#                             denomination                education  ...  \
# 0                      Christ-katholisch           Fachhochschule  ...
# 1                      Christ-katholisch           Fachhochschule  ...
# 33  Evangelischreformiert/protestantisch  Höhere Berufsausbildung  ...
# 34  Evangelischreformiert/protestantisch  Höhere Berufsausbildung  ...
# 35  Evangelischreformiert/protestantisch  Höhere Berufsausbildung  ...
#
#       PROPN     PUNCT     SCONJ  SYM      VERB    X  Entities  pres_tense  \
# 0   0.03125  0.093750  0.000000  0.0  0.125000  0.0   0.09375    0.062500
# 1   0.00000  0.133333  0.033333  0.0  0.166667  0.0   0.00000    0.166667
# 33  0.00000  0.083333  0.000000  0.0  0.083333  0.0   0.00000    0.083333
# 34  0.00000  0.166667  0.083333  0.0  0.083333  0.0   0.00000    0.083333
# 35  0.06250  0.187500  0.000000  0.0  0.062500  0.0   0.06250    0.062500
#
#     imperative  first_person
# 0          0.0      0.000000
# 1          0.0      0.000000
# 33         0.0      0.083333
# 34         0.0      0.166667
# 35         0.0      0.000000
#
# [5 rows x 43 columns]

# %% [markdown]
# #### Mean and standard deviation for the features

# %%
syntactic_features = ['ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 
                    'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'SYM', 'VERB', 'X', 'Entities', 'pres_tense',
                    'imperative', 'first_person']

# %%
for feat in syntactic_features:
    print(feat, round(corpus_de[feat].mean(),2), round(corpus_de[feat].min(),2), 
          round(corpus_de[feat].max(),2), round(corpus_de[feat].std(),2))
# Out:
# ADJ 0.06 0.0 0.43 0.05
# ADP 0.08 0.0 0.43 0.05
# ADV 0.11 0.0 0.62 0.07
# AUX 0.08 0.0 0.38 0.05
# CCONJ 0.03 0.0 0.23 0.03
# DET 0.12 0.0 0.36 0.06
# INTJ 0.0 0.0 0.0 0.0
# NOUN 0.21 0.0 0.8 0.07
# NUM 0.0 0.0 0.25 0.02
# PART 0.02 0.0 0.27 0.03
# PRON 0.05 0.0 0.4 0.05
# PROPN 0.01 0.0 0.38 0.03
# PUNCT 0.12 0.0 0.5 0.05
# SCONJ 0.01 0.0 0.17 0.02
# SYM 0.0 0.0 0.0 0.0
# VERB 0.09 0.0 0.5 0.05
# X 0.0 0.0 0.22 0.01
# Entities 0.04 0.0 0.62 0.05
# pres_tense 0.08 0.0 0.3 0.04
# imperative 0.0 0.0 0.11 0.0
# first_person 0.02 0.0 0.5 0.05

# %% [markdown]
# #### Save the prepared corpus for OLS regression
#
# The OLS regression is conducted in the R script.

# %%
corpus_de.shape
# Out:
# (11289, 43)

# %%
corpus_de.to_csv('corpus_de_ols_1_nondummy_nomv.csv', sep="\t", index=False)
